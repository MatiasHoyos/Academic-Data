# %%
#UPDATE this cell with your data source + Dictionary/Codebook
#data source: https://www.census.gov/data/datasets/time-series/demo/cps/cps-asec.2021.html
#data dictionary: https://www2.census.gov/programs-surveys/cps/datasets/2021/march/asec2021_ddl_pub_full.pdf
#import necessary libaries
import pandas as pd
import matplotlib

#name file path (you will have download your own dataset and populate the path and choose the appropriate cell to execute)
file = 'satgpa.csv' # <-- edit this value! 

#you will run just ONE of the next four code blocks, depending on the file type of your dataset

#read data from CSV (.csv) & print head
df = pd.read_csv("satgpa.csv")
print(df.head())

#list columns in data frame
print(list(df))
print(len(df))
#output frequency table of chosen column in dataset
col = 'hs_gpa' #<-edit this value! column name as it appears in dataframe
col_name = 'GPA IN HS' #<-edit this value! descriptive name for column
freq = df[col].value_counts().rename_axis(col_name).reset_index(name='freq')
freq = freq.sort_values(by = col_name)
print(freq)


#prints updated frequency table
print(freq)
#create frequency chart
ax = freq.plot.barh(x=col_name, y='freq', rot=0)

quant_col = "hs_gpa"
mean = df[quant_col].mean()
print("this is the mean", mean)

median = df[quant_col].median()
print("this is the median", median)

sd =  df[quant_col].std()
print("the following is the data regarding GPA in highschool for 1000 students in a top college")
print("this is the standard deviation", sd)
# Out:
#    sex  sat_v  sat_m  sat_sum  hs_gpa  fy_gpa
# 0    1     65     62      127    3.40    3.18
# 1    2     58     64      122    4.00    3.33
# 2    2     56     60      116    3.75    3.25
# 3    1     42     53       95    3.75    2.42
# 4    1     55     52      107    4.00    2.63
# ['sex', 'sat_v', 'sat_m', 'sat_sum', 'hs_gpa', 'fy_gpa']
# 1000
#     GPA IN HS  freq
# 30       1.80     1
# 19       2.00    15
# 33       2.03     1
# 23       2.10     9
# 22       2.20    12
# 24       2.25     7
# 17       2.30    22
# 20       2.40    14
# 28       2.47     1
# 3        2.50    59
# 29       2.56     1
# 16       2.60    25
# 25       2.67     4
# 8        2.70    44
# 32       2.74     1
# 15       2.75    27
# 4        2.80    56
# 12       2.90    35
# 1        3.00    98
# 34       3.04     1
# 11       3.10    36
# 9        3.20    43
# 14       3.25    32
# 10       3.30    37
# 26       3.33     3
# 13       3.40    32
# 2        3.50    97
# 18       3.60    17
# 27       3.67     2
# 7        3.70    45
# 5        3.75    45
# 6        3.80    45
# 21       3.90    12
# 0        4.00   120
# 31       4.50     1
#     GPA IN HS  freq
# 30       1.80     1
# 19       2.00    15
# 33       2.03     1
# 23       2.10     9
# 22       2.20    12
# 24       2.25     7
# 17       2.30    22
# 20       2.40    14
# 28       2.47     1
# 3        2.50    59
# 29       2.56     1
# 16       2.60    25
# 25       2.67     4
# 8        2.70    44
# 32       2.74     1
# 15       2.75    27
# 4        2.80    56
# 12       2.90    35
# 1        3.00    98
# 34       3.04     1
# 11       3.10    36
# 9        3.20    43
# 14       3.25    32
# 10       3.30    37
# 26       3.33     3
# 13       3.40    32
# 2        3.50    97
# 18       3.60    17
# 27       3.67     2
# 7        3.70    45
# 5        3.75    45
# 6        3.80    45
# 21       3.90    12
# 0        4.00   120
# 31       4.50     1
# this is the mean 3.198100000000001
# this is the median 3.2
# the following is the data regarding GPA in highschool for 1000 students in a top college
# this is the standard deviation 0.5416474609669759
